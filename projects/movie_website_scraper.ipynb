# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = "https://www.imdb.com/chart/top/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

response = requests.get(url, headers=headers)


soup = BeautifulSoup(response.text, "html.parser")
container = soup.select("li.ipc-metadata-list-summary-item")

movies = []

for movie in container:
    title = movie.find("h3", class_="ipc-title__text").text
    year = movie.find("span", class_="sc-a55f6282-6 iMumIM cli-title-metadata-item").text
    rating = movie.find("span", class_="ipc-rating-star--rating").text
    

    movie_details = {
        "Title": title,
        "Year": year,
        "Rating": rating,
        
    }
    movies.append(movie_details)

df = pd.DataFrame(movies)
df
# Out:
#                                                 Title  Year Rating  Rank
# 0                            The Shawshank Redemption  1994    9.3  None
# 1                                       The Godfather  1972    9.2  None
# 2                                     The Dark Knight  2008    9.1  None
# 3                               The Godfather Part II  1974    9.0  None
# 4                                        12 Angry Men  1957    9.0  None
# 5       The Lord of the Rings: The Return of the King  2003    9.0  None
# 6                                    Schindler's List  1993    9.0  None
# 7   The Lord of the Rings: The Fellowship of the Ring  2001    8.9  None
# 8                                        Pulp Fiction  1994    8.8  None
# 9                      The Good, the Bad and the Ugly  1966    8.8  None
# 10              The Lord of the Rings: The Two Towers  2002    8.8  None
# 11                                       Forrest Gump  1994    8.8  None
# 12                                         Fight Club  1999    8.8  None
# 13                                          Inception  2010    8.8  None
# 14     Star Wars: Episode V - The Empire Strikes Back  1980    8.7  None
# 15                                         The Matrix  1999    8.7  None
# 16                                         GoodFellas  1990    8.7  None
# 17                                       Interstellar  2014    8.7  None
# 18                    One Flew Over the Cuckoo's Nest  1975    8.6  None
# 19                                              Se7en  1995    8.6  None
# 20                              It's a Wonderful Life  1946    8.6  None
# 21                           The Silence of the Lambs  1991    8.6  None
# 22                                      Seven Samurai  1954    8.6  None
# 23                                Saving Private Ryan  1998    8.6  None
# 24                                     The Green Mile  1999    8.6  None
