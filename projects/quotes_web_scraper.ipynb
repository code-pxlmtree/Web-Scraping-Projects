# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

base_url = "https://quotes.toscrape.com/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

for page in range(1, 11):
    page_url = f"{base_url}/page/{page}"
    
    response = requests.get(page_url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")
    container = soup.find_all("div", class_="quote")

    quotes = []

    for quote in container:
        quote_text = quote.find("span", class_="text").text
        author = quote.find("small", class_="author").text
        tags = [tag.text for tag in quote.find_all("a", class_="tag")]

        author_link = base_url + quote.find("a")["href"]
    

        quote_details = {
            "Quote": quote_text,
            "Author": author,
            "Tags": tags,
            "Author_Link": author_link 
        }
        quotes.append(quote_details)

df = pd.DataFrame(quotes)

df
# Out:
#                                                Quote              Author  \
# 0  “The truth." Dumbledore sighed. "It is a beaut...        J.K. Rowling
# 1  “I'm the one that's got to die when it's time ...        Jimi Hendrix
# 2         “To die will be an awfully big adventure.”         J.M. Barrie
# 3  “It takes courage to grow up and become who yo...       E.E. Cummings
# 4  “But better to get hurt by the truth than comf...     Khaled Hosseini
# 5  “You never really understand a person until yo...          Harper Lee
# 6  “You have to write the book that wants to be w...   Madeleine L'Engle
# 7  “Never tell the truth to people who are not wo...          Mark Twain
# 8        “A person's a person, no matter how small.”           Dr. Seuss
# 9  “... a mind needs books as a sword needs a whe...  George R.R. Martin
#
#                                                 Tags  \
# 0                                            [truth]
# 1                                      [death, life]
# 2                                  [adventure, love]
# 3                                          [courage]
# 4                                             [life]
# 5                              [better-life-empathy]
# 6  [books, children, difficult, grown-ups, write,...
# 7                                            [truth]
# 8                                    [inspirational]
# 9                                      [books, mind]
#
#                                          Author_Link
# 0    https://quotes.toscrape.com//author/J-K-Rowling
# 1   https://quotes.toscrape.com//author/Jimi-Hendrix
# 2     https://quotes.toscrape.com//author/J-M-Barrie
# 3   https://quotes.toscrape.com//author/E-E-Cummings
# 4  https://quotes.toscrape.com//author/Khaled-Hos...
# 5     https://quotes.toscrape.com//author/Harper-Lee
# 6  https://quotes.toscrape.com//author/Madeleine-...
# 7     https://quotes.toscrape.com//author/Mark-Twain
# 8       https://quotes.toscrape.com//author/Dr-Seuss
# 9  https://quotes.toscrape.com//author/George-R-R...
